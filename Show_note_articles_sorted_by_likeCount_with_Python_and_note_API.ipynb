# %% [markdown]
# <a href="https://colab.research.google.com/github/rena-h/show-from-note-api/blob/main/Show_note_articles_sorted_by_likeCount_with_Python_and_note_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import json
import time
from tqdm import tqdm

# Fill in note user name
# https://note.com/XXX
user_name="XXX"

# note API
user_api_url="https://note.com/api/v2/creators/%s"%user_name
contents_api_url="https://note.com/api/v2/creators/%s/contents"%user_name

# Get user info
res = requests.get(user_api_url).content
df = pd.read_json(res)

# 取得秒数間隔の指定
interval = 1

# Get note_count
note_count = df['data']['noteCount']

# 総取得ページ数
page_num = (note_count//6) + 1

# 個別ページの取得
df2 = pd.DataFrame()

keys = ["name", "likeCount", "noteUrl", "publishAt"]

for page in tqdm(range(page_num)):

   page = page + 1

   payload = {'kind':'note', 'page':page}
   res = requests.get(contents_api_url, params=payload).content

   df = pd.read_json(res)           

   df_notes = []
   for i in range(len(df["data"]["contents"])):
     d = {k: v for k, v in df["data"]["contents"][i].items() if k in keys}
     df_notes.append(d)
   
   # 展開して新しいデータフレームに行として追加していく
   for i in range(len(df_notes)):
       df_n = pd.DataFrame(df_notes[i].values(), index=df_notes[i].keys()).T
       df2 = pd.concat([df2, df_n])

   time.sleep(interval)
   
# 重複行を削除する
df2.drop_duplicates(subset='noteUrl', inplace=True)

# like数順に並び替え
df2 = df2.sort_values('likeCount', ascending=False)

# インデックスの振り直し
df2.reset_index(drop=True, inplace=True)
df2.index = df2.index + 1

# Convert to a DataFrame and render.
pd.set_option('display.max_rows', 100)
pd.DataFrame.from_dict(df2)
# Out:
# 100%|██████████| 5/5 [00:07<00:00,  1.59s/it]
#                                                  name  ...                                           noteUrl
# 1                     stand.fmの会社紹介資料(エンジニア向け)を公開しました  ...  https://note.com/standfm_company/n/n9ed7e3c42b99
# 2                           stand.fmのnoteマガジンを3つスタート！  ...  https://note.com/standfm_company/n/n90a79f320cdd
# 3     Engineer interview Vol.1 ~ @matsumana エンジニア/SRE  ...  https://note.com/standfm_company/n/n7ec374fa9b30
# 4                       hidekのエンジニアと長話 第3-1回【全文書き起こし】  ...  https://note.com/standfm_company/n/n193b0dd09da1
# 5               Engineer interview Vol.2 ~ エンジニア 三堀さん  ...  https://note.com/standfm_company/n/n7159ecaf7f7c
# 6                 ReactNativeをv0.63.3にアップグレードしてハマったこと  ...  https://note.com/standfm_company/n/nfad4d6a1af8b
# 7        React NativeアプリでコラボLIVE配信ーアーキテクチャと使用ライブラリの概要  ...  https://note.com/standfm_company/n/nc9d5eb129bc7
# 8                                      新オフィスができました！歓喜  ...  https://note.com/standfm_company/n/naf8e0e6c7751
# 9                       hidekのエンジニアと長話 第3-2回【全文書き起こし】  ...  https://note.com/standfm_company/n/ne35216f04472
# 10  【LT全文書き起こしました】Tech Stand #1 React Native 中上級者向...  ...  https://note.com/standfm_company/n/n3152b2b05060
# 11             Engineer interview Vol.3 ~エンジニア 冨田 一喜~  ...  https://note.com/standfm_company/n/n93efe0e0f156
# 12  クロスプラットフォーム開発 Flutter x React NativeーTECH STAN...  ...  https://note.com/standfm_company/n/nfade4cf2c066
# 13                      hidekのエンジニアと長話 第2-3回【全文書き起こし】  ...  https://note.com/standfm_company/n/n31df84515691
# 14                      hidekのエンジニアと長話 第3-4回【全文書き起こし】  ...  https://note.com/standfm_company/n/n913f8918a246
# 15                      hidekのエンジニアと長話 第3-3回【全文書き起こし】  ...  https://note.com/standfm_company/n/nb7e387418536
# 16                                オンライン会社説明会を定期開催します！  ...  https://note.com/standfm_company/n/n851c7541d171
# 17              Engineer interview Vol.4 ~前田さん エンジニア~  ...  https://note.com/standfm_company/n/nea4203c897fa
# 18                      hidekのエンジニアと長話 第1-2回【全文書き起こし】  ...  https://note.com/standfm_company/n/n79a1ce010694
# 19                      hidekのエンジニアと長話 第4-1回【全文書き起こし】  ...  https://note.com/standfm_company/n/n3bb41549e5b8
# 20                      hidekのエンジニアと長話 第2-1回【全文書き起こし】  ...  https://note.com/standfm_company/n/n358174dc28f5
# 21                TECH STAND #2 React Native イベントレポート  ...  https://note.com/standfm_company/n/neadab6b1d73f
# 22                      hidekのエンジニアと長話 第1-1回【全文書き起こし】  ...  https://note.com/standfm_company/n/n65c6d1d750ab
# 23        「マイクロインタラクション with React Native」のテーマでLTしました  ...  https://note.com/standfm_company/n/n0c9f0e830381
# 24      メルペイVPoEのhidekさんも配信開始！stand.fmで聴けるTech系おすすめ放送  ...  https://note.com/standfm_company/n/nda01bcc16636
# 25                      hidekのエンジニアと長話 第4-2回【全文書き起こし】  ...  https://note.com/standfm_company/n/n2c5eb6333651
# 26                      hidekのエンジニアと長話 第2-2回【全文書き起こし】  ...  https://note.com/standfm_company/n/nc0f9114214df
# 27                      hidekのエンジニアと長話 第4-3回【全文書き起こし】  ...  https://note.com/standfm_company/n/n7c725d3951e8
# 28                      hidekのエンジニアと長話 第1-3回【全文書き起こし】  ...  https://note.com/standfm_company/n/n71c5952ba212
#
# [28 rows x 4 columns]
